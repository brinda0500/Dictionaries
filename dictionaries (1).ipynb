# %%
dict={'name':'brinda','designation':'frontend developer','qual':'b.tech','univ':'cmr'}
print(dict['name'])


print(dict['qual'])
# Out:
# brinda
# b.tech

# %%
dict={'name':'Brinda','designation':'frontend developer','qual':'b.tech','univ':'cmr'}

dict['name']='ramesh'

print(dict['name'])

dict['class']='cse7sem'

print(dict['class'])
# Out:
# ramesh
# cse7sem

# %%
dict={'name':'brinda','designation':'frontend developer','qual':'b.tech','univ':'cmr'}


del dict['designation']

#print(dict['designation'])

dict.clear()

#print(dict['name'])

del dict

# %%
dict={'name':'brinda','designation':'frontend','qual':'b.tech','univ':'cmr', 'name':'ananya'}


print(dict['name'])

print(len(dict))
# Out:
# ananya
# 4

# %%
dict={'name':'brinda','designation':'frontend developer','qual':'b.tech','univ':'cmr', 'name':'ananya'}


print(dict.values())

print(dict.items())

print(dict.keys())
# Out:
# dict_values(['ananya', 'frontend developer', 'b.tech', 'cmr'])
# dict_items([('name', 'ananya'), ('designation', 'frontend developer'), ('qual', 'b.tech'), ('univ', 'cmr')])
# dict_keys(['name', 'designation', 'qual', 'univ'])

# %%
dict={'name':'brinda','designation':'frontend developer','qual':'b.tech','univ':'cmr', 'name':'ananya'}


print(dict['name'])

print(dict.get('edu',"nothing"))
# Out:
# ananya
# nothing

# %%
dict={'name':'brinda','designation':'frontend developer','qual':'b.tech','univ':'cmr', 'name':'ananya'}


dict2=dict.copy()

print(dict2['name'])

print(len(dict2))
# Out:
# ananya
# 4

# %%
dict={'name':'brinda','designation':'frontend developer','qual':'b.tech','univ':'cmr', 'name':'brinda'}


dict2={'edu':'btech-mtech','students':'7sem'}

print(dict)
print(dict2)

dict.update(dict2)

print(dict)
# Out:
# {'name': 'brinda', 'designation': 'frontend developer', 'qual': 'b.tech', 'univ': 'cmr'}
# {'edu': 'btech-mtech', 'students': '7sem'}
# {'name': 'brinda', 'designation': 'frontend developer', 'qual': 'b.tech', 'univ': 'cmr', 'edu': 'btech-mtech', 'students': '7sem'}
